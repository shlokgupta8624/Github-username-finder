# %% [markdown]
# <a href="https://colab.research.google.com/github/shlokgupta8624/Github-username-finder/blob/main/Copy_of_Welcome_To_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # New Section

# %%
print("hii:")
# Out:
# hii:

# %%
import pandas as pd
import numpy as np

# %%
cont = ["india", "pakistn","usa","nepat"]
pd.Series(cont)
# Out:
# 0      india
# 1    pakistn
# 2        usa
# 3      nepat
# dtype: object

# %%
print("hi")

# %%
run= [15,25,42,521,12,25,]
pd.Series(run)
# Out:
# 0     15
# 1     25
# 2     42
# 3    521
# 4     12
# 5     25
# dtype: int64

# %%
makes = [64,40,50,10]
sub = ["math","english","hindi","IT"]

makes_series =  pd.Series(makes,index=sub,name = 'shlok gupta ')

# %%
result = {
    "math": 64,
    "english": 40,
    "hindi": 50,
    "IT": 10
}
pd.Series(result,name="ii")
# Out:
# math       64
# english    40
# hindi      50
# IT         10
# Name: ii, dtype: int64

# %%
makes_series.size
# Out:
# 4

# %%
makes_series.dtype
makes_series.name
makes_series.index
makes_series.values
# Out:
# array([64, 40, 50, 10])

# %%
import numpy as np
import pandas as pd
path = "/content/movies_data_1500.csv"
newpath = "/content/student_marks.csv"

# df = pd.read_csv(path).squeeze("columns")
# print("\nStudent Marks Data:")
# print(df.head(20))
s = pd.read_csv(path)
df = pd.read_csv(newpath)
# print(df)
# print(df.he`a`d(20))
# print(df.tail())
# # print(s.sample(5))
# print(df.value_counts())
# print(df.sort_values(by='Marks', ascending=False))
# print (df.count())
# print(df.sum(numeric_only=True))
# print(df.product(numeric_only=True))
# print(df.mean(numeric_only=True))
# print(s.mode(numeric_only=True))
# print(df.std(numeric_only=True))
# print(df.min())
# print(df.max())
# print(df.describe())
x = pd.Series([12,13,14,15,16,17,18,19])
print(x[1])
# print(df)
# print(df[15:])
# print(df[["Marks"]])
# a = df.loc[1, "Marks"] = 100
# print(a)
# print(df)
# a = df.loc[2:4, "Marks"] = 100
marks = df["Marks"]
print(marks)
# Out:
# 13
# 0     78
# 1     85
# 2     67
# 3     92
# 4     74
# 5     88
# 6     69
# 7     81
# 8     95
# 9     73
# 10    84
# 11    77
# 12    90
# 13    66
# 14    79
# 15    83
# 16    71
# 17    87
# 18    76
# 19    89
# Name: Marks, dtype: int64

# %%
print(len(df))
print(type(a))
print(dir(df))
df.sort_values(by="Marks")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-559/957573493.py in <cell line: 0>()
# ----> 1 print(len(df))
#       2 print(type(a))
#       3 print(dir(df))
#       4 df.sort_values(by="Marks")
#       5
#
# NameError: name 'df' is not defined

# %%
'Movie_3' in s["Title"].values

for i in df:
  print(i)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_245/1561574129.py in <cell line: 0>()
# ----> 1 'Movie_3' in s["Title"].values
#       2
#       3 for i in df:
#       4   print(i)
#
# NameError: name 's' is not defined

# %%
for i in s:
  print(i)
# Out:
# Movie ID
# Title
# Year
# Genre
# Rating

# %%
# 100 - marks
# Out:
# 0     22
# 1     15
# 2     33
# 3      8
# 4     26
# 5     12
# 6     31
# 7     19
# 8      5
# 9     27
# 10    16
# 11    23
# 12    10
# 13    34
# 14    21
# 15    17
# 16    29
# 17    13
# 18    24
# 19    11
# Name: Marks, dtype: int64

# %%
marks[marks >=10].size
marks[marks==90]
# Out:
# 12    90
# Name: Marks, dtype: int64

# %%
df.plot()
# Out:
# <Axes: >

# %%
df.plot(kind="bar")
# Out:
# <Axes: >

# %%
student_data = [

    [100,80,10],
    [90,70,7],
    [120,100,14],
    [80,50,2]
]
pd.DataFrame(student_data,columns=['iq','marks','package'])
# Out:
#     iq  marks  package
# 0  100     80       10
# 1   90     70        7
# 2  120    100       14
# 3   80     50        2

# %%
student_dict ={
    'name' : ['Nitish','Ankit','Yash','Shlok'],
    'iq' :[100,90,120,80],
    'marks':[80,70,100,50],
    'package':[10,7,14,2]
}
student = pd.DataFrame(student_dict)

student.set_index('name', inplace=True)
student
# Out:
#          iq  marks  package
# name
# Nitish  100     80       10
# Ankit    90     70        7
# Yash    120    100       14
# Shlok    80     50        2

# %%
move= pd.read_csv('/content/movies.csv')
move
# Out:
#                                    title_x     imdb_id  \
# 0                 Uri: The Surgical Strike   tt8291224
# 1                            Battalion 609   tt9472208
# 2     The Accidental Prime Minister (film)   tt6986710
# 3                          Why Cheat India   tt8108208
# 4                          Evening Shadows   tt6028796
# ...                                    ...         ...
# 1624                 Tera Mera Saath Rahen   tt0301250
# 1625                  Yeh Zindagi Ka Safar   tt0298607
# 1626                       Sabse Bada Sukh   tt0069204
# 1627                                 Daaka  tt10833860
# 1628                              Humsafar   tt2403201
#
#                                             poster_path  \
# 0     https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                   NaN
# 2     https://upload.wikimedia.org/wikipedia/en/thum...
# 3     https://upload.wikimedia.org/wikipedia/en/thum...
# ...

# %%
ipl = pd.read_csv('/content/ipl-matches.csv')
ipl
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_2107/792386719.py in <cell line: 0>()
# ----> 1 ipl = pd.read_csv('/content/ipl-matches.csv')
#       2 ipl
#
# NameError: name 'pd' is not defined

# %%
move.shape
ipl.shape
ipl.dtypes
# Out:
# ID                   int64
# City                object
# Date                object
# Season              object
# MatchNumber         object
# Team1               object
# Team2               object
# Venue               object
# TossWinner          object
# TossDecision        object
# SuperOver           object
# WinningTeam         object
# WonBy               object
# Margin             float64
# method              object
# Player_of_Match     object
# Team1Players        object
# Team2Players        object
# Umpire1             object
# Umpire2             object
# dtype: object

# %%
ipl.index
ipl.columns
# Out:
# Index(['ID', 'City', 'Date', 'Season', 'MatchNumber', 'Team1', 'Team2',
#        'Venue', 'TossWinner', 'TossDecision', 'SuperOver', 'WinningTeam',
#        'WonBy', 'Margin', 'method', 'Player_of_Match', 'Team1Players',
#        'Team2Players', 'Umpire1', 'Umpire2'],
#       dtype='object')

# %%
student.values
ipl.values
# Out:
# array([[1312200, 'Ahmedabad', '2022-05-29', ...,
#         "['WP Saha', 'Shubman Gill', 'MS Wade', 'HH Pandya', 'DA Miller', 'R Tewatia', 'Rashid Khan', 'R Sai Kishore', 'LH Ferguson', 'Yash Dayal', 'Mohammed Shami']",
#         'CB Gaffaney', 'Nitin Menon'],
#        [1312199, 'Ahmedabad', '2022-05-27', ...,
#         "['YBK Jaiswal', 'JC Buttler', 'SV Samson', 'D Padikkal', 'SO Hetmyer', 'R Parag', 'R Ashwin', 'TA Boult', 'YS Chahal', 'M Prasidh Krishna', 'OC McCoy']",
#         'CB Gaffaney', 'Nitin Menon'],
#        [1312198, 'Kolkata', '2022-05-25', ...,
#         "['Q de Kock', 'KL Rahul', 'M Vohra', 'DJ Hooda', 'MP Stoinis', 'E Lewis', 'KH Pandya', 'PVD Chameera', 'Mohsin Khan', 'Avesh Khan', 'Ravi Bishnoi']",
#         'J Madanagopal', 'MA Gough'],
#        ...,
#        [335984, 'Delhi', '2008-04-19', ...,
#         "['T Kohli', 'YK Pathan', 'SR Watson', 'M Kaif', 'DS Lehmann', 'RA Jadeja', 'M Rawat', 'D Salunkhe', 'SK Warne', 'SK Trivedi', 'MM Patel']",
# ...

# %%
move.head()
move.tail()
ipl.sample(5)
# Out:
#           ID       City        Date   Season MatchNumber  \
# 655   548355     Mumbai  2012-05-06     2012          49
# 590   598035     Raipur  2013-04-28     2013          39
# 314  1082650  Hyderabad  2017-05-21     2017       Final
# 167  1216507        NaN  2020-10-11  2020/21          26
# 270  1136604     Indore  2018-05-12     2018          44
#
#                      Team1                   Team2  \
# 655         Mumbai Indians     Chennai Super Kings
# 590       Delhi Daredevils           Pune Warriors
# 314         Mumbai Indians  Rising Pune Supergiant
# 167    Sunrisers Hyderabad        Rajasthan Royals
# 270  Kolkata Knight Riders         Kings XI Punjab
#
#                                                 Venue           TossWinner  \
# 655                                  Wankhede Stadium       Mumbai Indians
# 590  Shaheed Veer Narayan Singh International Stadium        Pune Warriors
# 314         Rajiv Gandhi International Stadium, Uppal       Mumbai Indians
# ...

# %%
move.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1629 entries, 0 to 1628
# Data columns (total 18 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   title_x           1629 non-null   object
#  1   imdb_id           1629 non-null   object
#  2   poster_path       1526 non-null   object
#  3   wiki_link         1629 non-null   object
#  4   title_y           1629 non-null   object
#  5   original_title    1629 non-null   object
#  6   is_adult          1629 non-null   int64
#  7   year_of_release   1629 non-null   int64
#  8   runtime           1629 non-null   object
#  9   genres            1629 non-null   object
#  10  imdb_rating       1629 non-null   float64
#  11  imdb_votes        1629 non-null   int64
#  12  story             1609 non-null   object
#  13  summary           1629 non-null   object
#  14  tagline           557 non-null    object
#  15  actors            1624 non-null   object
# ...

# %%
move.describe()
ipl.describe()
# Out:
#                  ID      Margin
# count  9.500000e+02  932.000000
# mean   8.304852e+05   17.056867
# std    3.375678e+05   21.633109
# min    3.359820e+05    1.000000
# 25%    5.012612e+05    6.000000
# 50%    8.297380e+05    8.000000
# 75%    1.175372e+06   19.000000
# max    1.312200e+06  146.000000

# %%
move.isnull().sum()
# Out:
# title_x                0
# imdb_id                0
# poster_path          103
# wiki_link              0
# title_y                0
# original_title         0
# is_adult               0
# year_of_release        0
# runtime                0
# genres                 0
# imdb_rating            0
# imdb_votes             0
# story                 20
# summary                0
# tagline             1072
# actors                 5
# wins_nominations     922
# release_date         107
# dtype: int64

# %%
ipl.duplicated().sum()
# Out:
# np.int64(0)

# %%
student
# Out:
#     iq  marks  package
# 0  100     80       10
# 1   90     70        7
# 2  120    100       14
# 3   80     50        2

# %%
student.rename(columns={'iq':'IQ','marks':'Marks','package':'Package'},inplace=True)
student
# Out:
#     IQ  Marks  Package
# 0  100     80       10
# 1   90     70        7
# 2  120    100       14
# 3   80     50        2

# %%
student.sum()
student.mean()
student.var()
# Out:
# IQ         97.50
# Marks      75.00
# Package     8.25
# dtype: float64

# %%
move['title_x']
ipl['Venue']
move
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_2107/1648006931.py in <cell line: 0>()
# ----> 1 move['title_x']
#       2 ipl['Venue']
#       3 move
#
# NameError: name 'move' is not defined

# %%
move[['title_x','actors']]
# Out:
#                                    title_x  \
# 0                 Uri: The Surgical Strike
# 1                            Battalion 609
# 2     The Accidental Prime Minister (film)
# 3                          Why Cheat India
# 4                          Evening Shadows
# ...                                    ...
# 1624                 Tera Mera Saath Rahen
# 1625                  Yeh Zindagi Ka Safar
# 1626                       Sabse Bada Sukh
# 1627                                 Daaka
# 1628                              Humsafar
#
#                                                  actors
# 0     Vicky Kaushal|Paresh Rawal|Mohit Raina|Yami Ga...
# 1     Vicky Ahuja|Shoaib Ibrahim|Shrikant Kamat|Elen...
# 2     Anupam Kher|Akshaye Khanna|Aahana Kumra|Atul S...
# 3     Emraan Hashmi|Shreya Dhanwanthary|Snighdadeep ...
# 4     Mona Ambegaonkar|Ananth Narayan Mahadevan|Deva...
# ...                                                 ...
# ...

# %%
move.iloc[0]
move.iloc[0:5]
# Out:
#                                 title_x    imdb_id  \
# 0              Uri: The Surgical Strike  tt8291224
# 1                         Battalion 609  tt9472208
# 2  The Accidental Prime Minister (film)  tt6986710
# 3                       Why Cheat India  tt8108208
# 4                       Evening Shadows  tt6028796
#
#                                          poster_path  \
# 0  https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                NaN
# 2  https://upload.wikimedia.org/wikipedia/en/thum...
# 3  https://upload.wikimedia.org/wikipedia/en/thum...
# 4                                                NaN
#
#                                            wiki_link  \
# 0  https://en.wikipedia.org/wiki/Uri:_The_Surgica...
# 1        https://en.wikipedia.org/wiki/Battalion_609
# 2  https://en.wikipedia.org/wiki/The_Accidental_P...
# 3      https://en.wikipedia.org/wiki/Why_Cheat_India
# 4      https://en.wikipedia.org/wiki/Evening_Shadows
#
# ...

# %%
move.iloc[[0,4,5]]
# Out:
#                     title_x    imdb_id  \
# 0  Uri: The Surgical Strike  tt8291224
# 4           Evening Shadows  tt6028796
# 5               Soni (film)  tt6078866
#
#                                          poster_path  \
# 0  https://upload.wikimedia.org/wikipedia/en/thum...
# 4                                                NaN
# 5  https://upload.wikimedia.org/wikipedia/en/thum...
#
#                                            wiki_link  \
# 0  https://en.wikipedia.org/wiki/Uri:_The_Surgica...
# 4      https://en.wikipedia.org/wiki/Evening_Shadows
# 5          https://en.wikipedia.org/wiki/Soni_(film)
#
#                     title_y            original_title  is_adult  \
# 0  Uri: The Surgical Strike  Uri: The Surgical Strike         0
# 4           Evening Shadows           Evening Shadows         0
# 5                      Soni                      Soni         0
#
#    year_of_release runtime            genres  imdb_rating  imdb_votes  \
# ...

# %%
student.loc['Yash']
# Out:
# iq         120
# marks      100
# package     14
# Name: Yash, dtype: int64

# %%
# ipl.head(2)
mast = ipl['MatchNumber'] == 'Final'
new_df = ipl[mast]
new_df[['Season','WinningTeam']]
# Out:
#       Season            WinningTeam
# 0       2022         Gujarat Titans
# 74      2021    Chennai Super Kings
# 134  2020/21         Mumbai Indians
# 194     2019         Mumbai Indians
# 254     2018    Chennai Super Kings
# 314     2017         Mumbai Indians
# 373     2016    Sunrisers Hyderabad
# 433     2015         Mumbai Indians
# 492     2014  Kolkata Knight Riders
# 552     2013         Mumbai Indians
# 628     2012  Kolkata Knight Riders
# 702     2011    Chennai Super Kings
# 775  2009/10    Chennai Super Kings
# 835     2009        Deccan Chargers
# 892  2007/08       Rajasthan Royals

# %%
move.iloc[0:2,0:3]
# Out:
#                     title_x    imdb_id  \
# 0  Uri: The Surgical Strike  tt8291224
# 1             Battalion 609  tt9472208
#
#                                          poster_path
# 0  https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                NaN

# %%
ipl[ipl['SuperOver'] == 'Y'].shape[0]
# Out:
# 14

# %%
city = ipl['City']== 'Kolkata'
ndf = ipl[city]
ndf[ndf['WinningTeam'] == 'Chennai Super Kings'].shape[0]
# Out:
# 5

# %%
(ipl[ipl['TossWinner'] == ipl['WinningTeam']].shape[0]/ipl.shape[0])*100
# Out:
# 51.473684210526315

# %%
move[(move['imdb_id'] > 8) & (move['imdb_votes'] >1000)].shape[0]
# Out:
# 0

# %%
# move.head(2)
mask1 = move['genres'].str.split('|').apply(lambda x : 'Action'in x)
mask2 = move['imdb_rating'] > 7.5
move[mask1 & mask2]
# Out:
#                             title_x  imdb_id  \
# 0          Uri: The Surgical Strike      NaN
# 41             Family of Thakurganj      NaN
# 84                        Mukkabaaz      NaN
# 106                           Raazi      NaN
# 110   Parmanu: The Story of Pokhran      NaN
# 112         Bhavesh Joshi Superhero      NaN
# 169                The Ghazi Attack      NaN
# 219                Raag Desh (film)      NaN
# 258                   Irudhi Suttru      NaN
# 280                       Laal Rang      NaN
# 297                     Udta Punjab      NaN
# 354                   Dangal (film)      NaN
# 362               Bajrangi Bhaijaan      NaN
# 365          Baby (2015 Hindi film)      NaN
# 393      Detective Byomkesh Bakshy!      NaN
# 449               Titli (2014 film)      NaN
# 536                   Haider (film)      NaN
# 589                    Vishwaroopam      NaN
# 625                     Madras Cafe      NaN
# 668         Paan Singh Tomar (film)      NaN
# ...

# %%
ipl['Team1'&'Team2']==
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-559/1973151948.py in <cell line: 0>()
# ----> 1 ipl['Team1'&'Team2']
#
# TypeError: unsupported operand type(s) for &: 'str' and 'str'

# %%
move['country']= 'india'
move.head(2)
# Out:
#                     title_x  imdb_id  \
# 0  Uri: The Surgical Strike      NaN
# 1             Battalion 609      NaN
#
#                                          poster_path  \
# 0  https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                NaN
#
#                                            wiki_link  \
# 0  https://en.wikipedia.org/wiki/Uri:_The_Surgica...
# 1        https://en.wikipedia.org/wiki/Battalion_609
#
#                     title_y            original_title  is_adult  \
# 0  Uri: The Surgical Strike  Uri: The Surgical Strike         0
# 1             Battalion 609             Battalion 609         0
#
#    year_of_release runtime            genres  imdb_rating  imdb_votes  \
# 0             2019     138  Action|Drama|War          8.4       35112
# 1             2019     131               War          4.1          73
#
#                                                story  \
# 0  Divided over five chapters  the film chronicle...
# ...

# %%
ipl["ID"] = ipl['ID'].astype('int32')
ipl.info()
# Out:
# ---------------------------------------------------------------------------
# RecursionError                            Traceback (most recent call last)
# /tmp/ipython-input-559/187248091.py in <cell line: 0>()
#       1 ipl["ID"] = ipl['ID'].astype('int32')
# ----> 2 ipl.info()
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/frame.py in info(self, verbose, buf, max_cols, memory_usage, show_counts)
#    3657             memory_usage=memory_usage,
#    3658         )
# -> 3659         info.render(
#    3660             buf=buf,
#    3661             max_cols=max_cols,
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/formats/info.py in render(self, buf, max_cols, verbose, show_counts)
#     510             show_counts=show_counts,
#     511         )
# --> 512         printer.to_buffer(buf)
#     513
#     514
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/formats/info.py in to_buffer(self, buf)
# ...

# %%
ipl['Team1']= ipl['Team1'].astype('category')
